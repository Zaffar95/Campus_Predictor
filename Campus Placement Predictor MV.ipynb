# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Placement_Data_Full_Class.csv')
df.head(10)
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
# 5      6      M  55.00   Others  49.80   Others   Science     67.25
# 6      7      F  46.00   Others  49.20   Others  Commerce     79.00
# 7      8      M  82.00  Central  64.00  Central   Science     66.00
# 8      9      M  73.00  Central  79.00  Central  Commerce     72.00
# 9     10      M  58.00  Central  70.00  Central  Commerce     61.00
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No    55.00         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes    86.50        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No    75.00        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No    66.00         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No    96.80        Mkt&Fin  55.50      Placed  425000.0
# 5   Sci&Tech    Yes    55.00        Mkt&Fin  51.58  Not Placed       NaN
# 6  Comm&Mgmt     No    74.28        Mkt&Fin  53.29  Not Placed       NaN
# 7   Sci&Tech    Yes    67.00        Mkt&Fin  62.14      Placed  252000.0
# 8  Comm&Mgmt     No    91.34        Mkt&Fin  61.29      Placed  231000.0
# 9  Comm&Mgmt     No    54.00        Mkt&Fin  52.21  Not Placed       NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
# seperating the categorical and numerical columns

catvars = list(df.select_dtypes(include=['object']).columns)

numvars = list(df.select_dtypes(include=['int32','int64','float32','float64']).columns)


print(catvars,numvars)
# Out:
# ['gender', 'ssc_b', 'hsc_b', 'hsc_s', 'degree_t', 'workex', 'specialisation', 'status'] ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
df.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
df.shape
# Out:
# (215, 15)

# %%
def plotdistplot(col):
    
    plt.figure(figsize=(15,7))
    sn.histplot(df['salary'],color='orange',)
    sn.histplot(df[col],color='black')

# %%
df['salary'].mode()[0]
# Out:
# 288655.4054054054

# %%
df['salary_mean'] = df['salary'].fillna(df['salary'].mean())
df['salary_median'] = df['salary'].fillna(df['salary'].median())
df['salary_mode'] = df['salary'].fillna(df['salary'].mode()[0])
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status         salary  \
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.000000
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.000000
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.000000
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed  288655.405405
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.000000
#
#      salary_mean  salary_median    salary_mode
# 0  270000.000000  270000.000000  270000.000000
# 1  200000.000000  200000.000000  200000.000000
# 2  250000.000000  250000.000000  250000.000000
# 3  288655.405405  288655.405405  288655.405405
# 4  425000.000000  425000.000000  425000.000000

# %%
sallist = ['salary_mean','salary_median','salary_mode']
for sal in sallist:
    plotdistplot(sal)

# %%
# filling the salary with mean

df['salary'] = df['salary'].fillna(df['salary'].mean())
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status         salary  \
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.000000
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.000000
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.000000
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed  288655.405405
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.000000
#
#      salary_mean  salary_median    salary_mode
# 0  270000.000000  270000.000000  270000.000000
# 1  200000.000000  200000.000000  200000.000000
# 2  250000.000000  250000.000000  250000.000000
# 3  288655.405405  288655.405405  288655.405405
# 4  425000.000000  425000.000000  425000.000000

# %%
df = df.drop(columns=['salary_mean', 'salary_median', 'salary_mode'],axis=1)
df.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %% [markdown]
# ## EDA

# %%
sn.countplot(x=df['status'],palette='plasma')
# Out:
# <AxesSubplot:xlabel='status', ylabel='count'>

# %%
def valuecount(col):
    
    return dict(df[col].value_counts())

def getcountplot(col):
    
    sn.countplot(x=df[col],palette='plasma')
    plt.xticks(rotation = 'vertical',fontweight = 'bold',fontsize = '10')
    plt.yticks(rotation = 'vertical',fontweight = 'bold',fontsize = '10')
    plt.show()
    

for col in catvars:
    print(f'Count Plot for feature {col} is shown ↓')
    getcountplot(col)
    print('='*75)
# Out:
# Count Plot for feature gender is shown ↓
# ===========================================================================
# Count Plot for feature ssc_b is shown ↓
# ===========================================================================
# Count Plot for feature hsc_b is shown ↓
# ===========================================================================
# Count Plot for feature hsc_s is shown ↓
# ===========================================================================
# Count Plot for feature degree_t is shown ↓
# ===========================================================================
# Count Plot for feature workex is shown ↓
# ===========================================================================
# Count Plot for feature specialisation is shown ↓
# ===========================================================================
# Count Plot for feature status is shown ↓
# ===========================================================================

# %%
getfinaldict = {}
for col in catvars:
    getfinaldict[col] = valuecount(col)
    
getfinaldict
# Out:
# {'gender': {'M': 139, 'F': 76},
#  'ssc_b': {'Central': 116, 'Others': 99},
#  'hsc_b': {'Others': 131, 'Central': 84},
#  'hsc_s': {'Commerce': 113, 'Science': 91, 'Arts': 11},
#  'degree_t': {'Comm&Mgmt': 145, 'Sci&Tech': 59, 'Others': 11},
#  'workex': {'No': 141, 'Yes': 74},
#  'specialisation': {'Mkt&Fin': 120, 'Mkt&HR': 95},
#  'status': {'Placed': 148, 'Not Placed': 67}}

# %%
# top science students placed

df[(df['degree_t']=='Sci&Tech')&(df['status']=='Placed')].sort_values(by = 'salary',ascending = False).reset_index().head(5)
# Out:
#    index  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b    hsc_s  degree_p  \
# 0    150    151      M  71.00  Central  58.66  Central  Science     58.00
# 1     77     78      M  64.00   Others  80.00   Others  Science     65.00
# 2    163    164      M  63.00   Others  67.00   Others  Science     64.00
# 3    174    175      M  73.24   Others  50.83   Others  Science     64.27
# 4     53     54      M  80.00   Others  70.00   Others  Science     72.00
#
#    degree_t workex  etest_p specialisation  mba_p  status    salary
# 0  Sci&Tech    Yes     56.0        Mkt&Fin  61.30  Placed  690000.0
# 1  Sci&Tech    Yes     69.0        Mkt&Fin  57.65  Placed  500000.0
# 2  Sci&Tech     No     75.0        Mkt&Fin  66.46  Placed  500000.0
# 3  Sci&Tech    Yes     64.0        Mkt&Fin  66.23  Placed  500000.0
# 4  Sci&Tech     No     87.0         Mkt&HR  71.04  Placed  450000.0

# %%
# top Comm&Mgt students placed

df[(df['degree_t']=='Comm&Mgmt')&(df['status']=='Placed')].sort_values(by = 'salary',ascending = False).reset_index().head(5)
# Out:
#    index  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0    119    120      M   60.8  Central   68.4  Central  Commerce      64.6
# 1    177    178      F   73.0  Central   97.0   Others  Commerce      79.0
# 2      4      5      M   85.8  Central   73.6  Central  Commerce      73.3
# 3     95     96      M   73.0  Central   78.0   Others  Commerce      65.0
# 4    210    211      M   80.6   Others   82.0   Others  Commerce      77.6
#
#     degree_t workex  etest_p specialisation  mba_p  status    salary
# 0  Comm&Mgmt    Yes    82.66        Mkt&Fin  64.34  Placed  940000.0
# 1  Comm&Mgmt    Yes    89.00        Mkt&Fin  70.81  Placed  650000.0
# 2  Comm&Mgmt     No    96.80        Mkt&Fin  55.50  Placed  425000.0
# 3  Comm&Mgmt    Yes    95.46        Mkt&Fin  62.16  Placed  420000.0
# 4  Comm&Mgmt     No    91.00        Mkt&Fin  74.49  Placed  400000.0

# %%
# max and min salary
# observation : max salary : 9,40,000 and min salary : 2,00,000

df[(df['salary']==max(df['salary'])) | (df['salary']==min(df['salary']))].sort_values(by='salary',ascending = False).reset_index()
# Out:
#    index  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0    119    120      M  60.80  Central  68.40  Central  Commerce     64.60
# 1      1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2     15     16      F  65.00  Central  75.00  Central  Commerce     69.00
# 3     44     45      F  77.00   Others  73.00   Others  Commerce     81.00
# 4     50     51      F  75.20  Central  73.20  Central   Science     68.40
# 5    107    108      M  82.00   Others  90.00   Others  Commerce     83.00
# 6    135    136      F  72.00  Central  56.00   Others   Science     69.00
#
#     degree_t workex  etest_p specialisation  mba_p  status    salary
# 0  Comm&Mgmt    Yes    82.66        Mkt&Fin  64.34  Placed  940000.0
# 1   Sci&Tech    Yes    86.50        Mkt&Fin  66.28  Placed  200000.0
# 2  Comm&Mgmt    Yes    72.00        Mkt&Fin  64.66  Placed  200000.0
# 3  Comm&Mgmt    Yes    89.00        Mkt&Fin  69.70  Placed  200000.0
# 4  Comm&Mgmt     No    65.00         Mkt&HR  62.98  Placed  200000.0
# 5  Comm&Mgmt     No    80.00         Mkt&HR  73.52  Placed  200000.0
# 6  Comm&Mgmt     No    55.60         Mkt&HR  65.63  Placed  200000.0

# %%
# students with salary more than avg salary science dept

df[(df['degree_t']=='Sci&Tech')&(df['salary']>df['salary'].mean())].sort_values(by = 'salary',ascending = False).reset_index()
# Out:
#     index  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b    hsc_s  degree_p  \
# 0     150    151      M  71.00  Central  58.66  Central  Science     58.00
# 1     174    175      M  73.24   Others  50.83   Others  Science     64.27
# 2      77     78      M  64.00   Others  80.00   Others  Science     65.00
# 3     163    164      M  63.00   Others  67.00   Others  Science     64.00
# 4      53     54      M  80.00   Others  70.00   Others  Science     72.00
# 5      39     40      M  81.00   Others  68.00   Others  Science     64.00
# 6     145    146      M  89.40   Others  65.66   Others  Science     71.25
# 7     128    129      M  80.40  Central  73.40  Central  Science     77.72
# 8      22     23      F  69.80   Others  60.80   Others  Science     72.23
# 9      24     25      M  76.50   Others  97.70   Others  Science     78.86
# 10     70     71      M  82.00   Others  61.00   Others  Science     62.00
# 11    178    179      M  68.00   Others  56.00   Others  Science     68.00
# 12    153    154      M  49.00   Others  59.00   Others  Science     65.00
# 13     37     38      F  79.00  Central  76.00  Central  Science     65.60
# 14     23     24      F  77.40   Others  60.00   Others  Science     64.74
# 15    160    161      M  87.00  Central  74.00  Central  Science     65.00
# 16     83     84      M  84.00   Others  79.00   Others  Science     68.00
# 17     84     85      M  70.00  Central  63.00   Others  Science     70.00
#
#     degree_t workex  etest_p specialisation  mba_p  status    salary
# 0   Sci&Tech    Yes    56.00        Mkt&Fin  61.30  Placed  690000.0
# 1   Sci&Tech    Yes    64.00        Mkt&Fin  66.23  Placed  500000.0
# 2   Sci&Tech    Yes    69.00        Mkt&Fin  57.65  Placed  500000.0
# 3   Sci&Tech     No    75.00        Mkt&Fin  66.46  Placed  500000.0
# 4   Sci&Tech     No    87.00         Mkt&HR  71.04  Placed  450000.0
# 5   Sci&Tech     No    93.00        Mkt&Fin  62.56  Placed  411000.0
# 6   Sci&Tech     No    72.00         Mkt&HR  63.23  Placed  400000.0
# 7   Sci&Tech    Yes    81.20         Mkt&HR  76.26  Placed  400000.0
# 8   Sci&Tech     No    55.53         Mkt&HR  68.81  Placed  360000.0
# 9   Sci&Tech     No    97.40        Mkt&Fin  74.01  Placed  360000.0
# 10  Sci&Tech     No    89.00        Mkt&Fin  65.45  Placed  360000.0
# 11  Sci&Tech     No    73.00         Mkt&HR  68.07  Placed  350000.0
# 12  Sci&Tech    Yes    86.00        Mkt&Fin  62.48  Placed  340000.0
# 13  Sci&Tech     No    58.00         Mkt&HR  55.47  Placed  320000.0
# 14  Sci&Tech    Yes    92.00        Mkt&Fin  63.62  Placed  300000.0
# 15  Sci&Tech    Yes    75.00         Mkt&HR  72.29  Placed  300000.0
# 16  Sci&Tech    Yes    84.00        Mkt&Fin  66.69  Placed  300000.0
# 17  Sci&Tech    Yes    55.00        Mkt&Fin  62.00  Placed  300000.0

# %%
# students with salary more than avg salary Comm&Mgmt dept

df[(df['degree_t']=='Comm&Mgmt')&(df['salary']>df['salary'].mean())].sort_values(by = 'salary',ascending = False).reset_index()
# Out:
#     index  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0     119    120      M  60.80  Central  68.40  Central  Commerce     64.60
# 1     177    178      F  73.00  Central  97.00   Others  Commerce     79.00
# 2       4      5      M  85.80  Central  73.60  Central  Commerce     73.30
# 3      95     96      M  73.00  Central  78.00   Others  Commerce     65.00
# 4      85     86      F  83.84   Others  89.83   Others  Commerce     77.20
# 5     210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 6      21     22      F  79.00   Others  76.00   Others  Commerce     85.00
# 7     101    102      M  63.00  Central  72.00  Central  Commerce     68.00
# 8     104    105      M  69.00  Central  63.00   Others   Science     65.00
# 9      57     58      M  68.00  Central  76.00  Central  Commerce     74.00
# 10    125    126      F  84.00  Central  73.00  Central  Commerce     73.00
# 11     28     29      M  76.76   Others  76.50   Others  Commerce     67.50
# 12     74     75      M  56.60  Central  64.80  Central  Commerce     70.20
# 13    132    133      M  67.00   Others  68.00   Others  Commerce     64.00
# 14    207    208      M  83.33  Central  78.00   Others  Commerce     61.00
# 15    200    201      M  69.00   Others  60.00   Others  Commerce     65.00
# 16     35     36      F  69.00  Central  78.00  Central  Commerce     72.00
# 17    172    173      M  73.00   Others  58.00   Others  Commerce     56.00
# 18    157    158      M  66.50  Central  62.50  Central  Commerce     60.90
# 19    147    148      M  70.00  Central  74.00  Central  Commerce     65.00
# 20    143    144      M  77.67   Others  64.89   Others  Commerce     70.67
# 21     81     82      M  81.70   Others  63.00   Others   Science     67.00
# 22     43     44      M  87.00   Others  87.00   Others  Commerce     68.00
# 23    116    117      M  68.20  Central  72.80  Central  Commerce     66.60
# 24    108    109      M  61.00  Central  82.00  Central  Commerce     69.00
# 25     16     17      M  63.00  Central  66.20  Central  Commerce     65.60
# 26    102    103      F  77.00   Others  61.00   Others  Commerce     68.00
# 27     96     97      F  76.00  Central  70.00  Central   Science     76.00
# 28     61     62      M  84.20  Central  73.40  Central  Commerce     66.89
# 29     90     91      F  85.00   Others  90.00   Others  Commerce     82.00
# 30    212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 31    171    172      M  80.00   Others  80.00   Others  Commerce     72.00
#
#      degree_t workex  etest_p specialisation  mba_p  status    salary
# 0   Comm&Mgmt    Yes    82.66        Mkt&Fin  64.34  Placed  940000.0
# 1   Comm&Mgmt    Yes    89.00        Mkt&Fin  70.81  Placed  650000.0
# 2   Comm&Mgmt     No    96.80        Mkt&Fin  55.50  Placed  425000.0
# 3   Comm&Mgmt    Yes    95.46        Mkt&Fin  62.16  Placed  420000.0
# 4   Comm&Mgmt    Yes    78.74        Mkt&Fin  76.18  Placed  400000.0
# 5   Comm&Mgmt     No    91.00        Mkt&Fin  74.49  Placed  400000.0
# 6   Comm&Mgmt     No    95.00        Mkt&Fin  69.06  Placed  393000.0
# 7   Comm&Mgmt     No    78.00         Mkt&HR  60.44  Placed  380000.0
# 8   Comm&Mgmt    Yes    55.00         Mkt&HR  58.23  Placed  360000.0
# 9   Comm&Mgmt     No    80.00        Mkt&Fin  63.59  Placed  360000.0
# 10  Comm&Mgmt     No    75.00        Mkt&Fin  73.33  Placed  350000.0
# 11  Comm&Mgmt    Yes    73.35        Mkt&Fin  64.15  Placed  350000.0
# 12  Comm&Mgmt     No    84.27        Mkt&Fin  67.20  Placed  336000.0
# 13  Comm&Mgmt    Yes    74.40         Mkt&HR  53.49  Placed  300000.0
# 14  Comm&Mgmt    Yes    88.56        Mkt&Fin  71.55  Placed  300000.0
# 15  Comm&Mgmt     No    87.55        Mkt&Fin  52.81  Placed  300000.0
# 16  Comm&Mgmt     No    71.00         Mkt&HR  62.74  Placed  300000.0
# 17  Comm&Mgmt     No    84.00         Mkt&HR  52.64  Placed  300000.0
# 18  Comm&Mgmt     No    93.40        Mkt&Fin  55.03  Placed  300000.0
# 19  Comm&Mgmt     No    83.00        Mkt&Fin  62.28  Placed  300000.0
# 20  Comm&Mgmt     No    89.00        Mkt&Fin  60.39  Placed  300000.0
# 21  Comm&Mgmt    Yes    86.00        Mkt&Fin  70.20  Placed  300000.0
# 22  Comm&Mgmt     No    95.00         Mkt&HR  62.90  Placed  300000.0
# 23  Comm&Mgmt    Yes    96.00        Mkt&Fin  70.85  Placed  300000.0
# 24  Comm&Mgmt     No    84.00        Mkt&Fin  58.31  Placed  300000.0
# 25  Comm&Mgmt    Yes    60.00        Mkt&Fin  62.54  Placed  300000.0
# 26  Comm&Mgmt    Yes    57.50        Mkt&Fin  61.31  Placed  300000.0
# 27  Comm&Mgmt    Yes    66.00        Mkt&Fin  64.44  Placed  300000.0
# 28  Comm&Mgmt     No    61.60        Mkt&Fin  62.48  Placed  300000.0
# 29  Comm&Mgmt     No    92.00        Mkt&Fin  68.03  Placed  300000.0
# 30  Comm&Mgmt    Yes    59.00        Mkt&Fin  69.72  Placed  295000.0
# 31  Comm&Mgmt    Yes    63.79        Mkt&Fin  66.04  Placed  290000.0

# %%
# maximum students placed are from comm&mgt

df.groupby(['degree_t'])['status'].count().plot(kind = 'bar',color = 'magenta')
# Out:
# <Axes: xlabel='degree_t'>

# %%
# Marketing and Finance specialisation are placed more

df.groupby(['specialisation'])['status'].count().plot(kind = 'bar',color = 'magenta')
# Out:
# <Axes: xlabel='specialisation'>

# %%
# females placed 35% and males 65%

df.groupby(['gender'])['status'].count().plot(kind = 'pie',autopct='%1.0f')
# Out:
# <AxesSubplot:ylabel='status'>

# %%
# max female salary ~ 6,50,000

temp = df[df['gender']=='F']
temp[temp['salary']==max(temp['salary'])].style.background_gradient(cmap = 'plasma')
# Out:
# <style type="text/css">
# #T_42e49_row0_col0, #T_42e49_row0_col2, #T_42e49_row0_col4, #T_42e49_row0_col7, #T_42e49_row0_col10, #T_42e49_row0_col12, #T_42e49_row0_col14 {
#   background-color: #0d0887;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_42e49">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_42e49_level0_col0" class="col_heading level0 col0" >sl_no</th>
#       <th id="T_42e49_level0_col1" class="col_heading level0 col1" >gender</th>
#       <th id="T_42e49_level0_col2" class="col_heading level0 col2" >ssc_p</th>
#       <th id="T_42e49_level0_col3" class="col_heading level0 col3" >ssc_b</th>
#       <th id="T_42e49_level0_col4" class="col_heading level0 col4" >hsc_p</th>
#       <th id="T_42e49_level0_col5" class="col_heading level0 col5" >hsc_b</th>
#       <th id="T_42e49_level0_col6" class="col_heading level0 col6" >hsc_s</th>
#       <th id="T_42e49_level0_col7" class="col_heading level0 col7" >degree_p</th>
#       <th id="T_42e49_level0_col8" class="col_heading level0 col8" >degree_t</th>
#       <th id="T_42e49_level0_col9" class="col_heading level0 col9" >workex</th>
#       <th id="T_42e49_level0_col10" class="col_heading level0 col10" >etest_p</th>
#       <th id="T_42e49_level0_col11" class="col_heading level0 col11" >specialisation</th>
#       <th id="T_42e49_level0_col12" class="col_heading level0 col12" >mba_p</th>
#       <th id="T_42e49_level0_col13" class="col_heading level0 col13" >status</th>
#       <th id="T_42e49_level0_col14" class="col_heading level0 col14" >salary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_42e49_level0_row0" class="row_heading level0 row0" >177</th>
#       <td id="T_42e49_row0_col0" class="data row0 col0" >178</td>
#       <td id="T_42e49_row0_col1" class="data row0 col1" >F</td>
#       <td id="T_42e49_row0_col2" class="data row0 col2" >73.000000</td>
#       <td id="T_42e49_row0_col3" class="data row0 col3" >Central</td>
#       <td id="T_42e49_row0_col4" class="data row0 col4" >97.000000</td>
#       <td id="T_42e49_row0_col5" class="data row0 col5" >Others</td>
#       <td id="T_42e49_row0_col6" class="data row0 col6" >Commerce</td>
#       <td id="T_42e49_row0_col7" class="data row0 col7" >79.000000</td>
#       <td id="T_42e49_row0_col8" class="data row0 col8" >Comm&Mgmt</td>
#       <td id="T_42e49_row0_col9" class="data row0 col9" >Yes</td>
#       <td id="T_42e49_row0_col10" class="data row0 col10" >89.000000</td>
#       <td id="T_42e49_row0_col11" class="data row0 col11" >Mkt&Fin</td>
#       <td id="T_42e49_row0_col12" class="data row0 col12" >70.810000</td>
#       <td id="T_42e49_row0_col13" class="data row0 col13" >Placed</td>
#       <td id="T_42e49_row0_col14" class="data row0 col14" >650000.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.groupby(['hsc_s'])['status'].count().plot(kind = 'pie',autopct='%1.0f%%',figsize=(15,7))
# Out:
# <Axes: ylabel='status'>

# %%
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status         salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.000000
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.000000
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.000000
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed  288655.405405
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.000000

# %%
getfinaldict
# Out:
# {'gender': {'M': 139, 'F': 76},
#  'ssc_b': {'Central': 116, 'Others': 99},
#  'hsc_b': {'Others': 131, 'Central': 84},
#  'hsc_s': {'Commerce': 113, 'Science': 91, 'Arts': 11},
#  'degree_t': {'Comm&Mgmt': 145, 'Sci&Tech': 59, 'Others': 11},
#  'workex': {'No': 141, 'Yes': 74},
#  'specialisation': {'Mkt&Fin': 120, 'Mkt&HR': 95},
#  'status': {'Placed': 148, 'Not Placed': 67}}

# %%
len(getfinaldict['status']),len(getfinaldict['degree_t'])
# Out:
# (2, 3)

# %%
boolcols = [key for key,value in getfinaldict.items() if len(getfinaldict[key])==2]
tripcols = [key for key in list(getfinaldict.keys()) if key not in boolcols]

print(boolcols,tripcols)
# Out:
# ['gender', 'ssc_b', 'hsc_b', 'workex', 'specialisation', 'status'] ['hsc_s', 'degree_t']

# %% [markdown]
# ## Label Encoding process

# %%
def labelencode(le,col):
    
    df[col] = le.fit_transform(df[col])
    
    
getmappings = {}
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for col in list(getfinaldict.keys()):
    labelencode(le,col)
    getmappings[col] = dict(zip(le.classes_,le.transform(le.classes_)))
    

df.head()
# Out:
#    gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  workex  \
# 0       1  67.00      1  91.00      1      1     58.00         2       0
# 1       1  79.33      0  78.33      1      2     77.48         2       1
# 2       1  65.00      0  68.00      0      0     64.00         0       0
# 3       1  56.00      0  52.00      0      2     52.00         2       0
# 4       1  85.80      0  73.60      0      1     73.30         0       0
#
#    etest_p  specialisation  mba_p  status         salary
# 0     55.0               1  58.80       1  270000.000000
# 1     86.5               0  66.28       1  200000.000000
# 2     75.0               0  57.80       1  250000.000000
# 3     66.0               1  59.43       0  288655.405405
# 4     96.8               0  55.50       1  425000.000000

# %%
# this was the internal mapping structure followed by label encoder for mapping

getmappings
# Out:
# {'gender': {0: 0, 1: 1},
#  'ssc_b': {0: 0, 1: 1},
#  'hsc_b': {0: 0, 1: 1},
#  'hsc_s': {0: 0, 1: 1, 2: 2},
#  'degree_t': {0: 0, 1: 1, 2: 2},
#  'workex': {0: 0, 1: 1},
#  'specialisation': {0: 0, 1: 1},
#  'status': {0: 0, 1: 1}}

# %%
# removing unwated columns

df = df.drop(['sl_no'],axis=1)
df.head(2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-f2e898b513e6> in <module>
#       1 # removing unwated columns
#       2
# ----> 3 df = df.drop(['sl_no'],axis=1)
#       4 df.head(2)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5280         if mask.any():
#    5281             if errors != "ignore":
# -> 5282                 raise KeyError(f"{labels[mask]} not found in axis")
#    5283             indexer = indexer[~mask]
#    5284         return self.delete(indexer)
#
# KeyError: "['sl_no'] not found in axis"

# %% [markdown]
# ## Numerical Columns EDA

# %%
numvars[1:]
# Out:
# ['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
import scipy.stats as stats

def getplots(df,col):
    
    plt.figure(figsize=(15,7))
    plt.subplot(1,3,1)
    plt.hist(df[col],color='magenta')
    
    plt.subplot(1,3,2)
    stats.probplot(df[col],dist='norm',plot=plt)
    
    plt.subplot(1,3,3)
    sn.boxplot(df[col],color='magenta')
    
    plt.show()
    
    
for col in numvars[1:]:
    print(f'Distribution plots for col : {col} are shown ↓')
    getplots(df,col)
    print('='*10)
# Out:
# Distribution plots for col : ssc_p are shown ↓
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ==========
# Distribution plots for col : hsc_p are shown ↓
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ==========
# Distribution plots for col : degree_p are shown ↓
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ==========
# Distribution plots for col : etest_p are shown ↓
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ==========
# Distribution plots for col : mba_p are shown ↓
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ==========
# Distribution plots for col : salary are shown ↓
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ==========

# %% [markdown]
# # Feature Selection

# %%
# checking for tightly correlated features


plt.figure(figsize=(15,7))
sn.heatmap(df.corr(),annot=True,cmap='plasma')
# Out:
# <AxesSubplot:>

# %%
data = df.copy()
test = data['status']
train = data.drop(['status','salary'],axis = 1)
train.head(2)
# Out:
#    gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  workex  \
# 0       1  67.00      1  91.00      1      1     58.00         2       0
# 1       1  79.33      0  78.33      1      2     77.48         2       1
#
#    etest_p  specialisation  mba_p
# 0     55.0               1  58.80
# 1     86.5               0  66.28

# %%
## extratrees classifier

from sklearn.ensemble import ExtraTreesClassifier
ec = ExtraTreesClassifier()
ec.fit(train,test)
# Out:
# ExtraTreesClassifier()

# %%
featbar = pd.Series(ec.feature_importances_,index=train.columns)
featbar.nlargest(7).plot(kind = 'barh')
# Out:
# <Axes: >

# %%
featbar.nlargest(7).plot(kind='pie',autopct='%1.0f%%',figsize = (15,7))
# Out:
# <Axes: >

# %%
# mutual classifier

from sklearn.feature_selection import mutual_info_classif
mc = mutual_info_classif(train,test)
ax = pd.Series(mc,index=train.columns)
ax.nlargest(7).plot(kind = 'barh')
# Out:
# <Axes: >

# %%
pd.Series(mc,index=train.columns).plot(kind = 'pie',autopct='%1.0f%%',figsize = (15,7))
# Out:
# <Axes: >

# %%
'''
Selecting the top 10 contributing features in both cases
and then we will do the intersection of both the results
so that we will get atleast top 5 most contributing features!

'''

featcol = list(featbar.nlargest(10).index)
mutclasif = list(ax.nlargest(10).index)
commoncols = list(set(featcol).intersection(set(mutclasif)))
print(commoncols)
# Out:
# ['ssc_p', 'hsc_p', 'degree_t', 'ssc_b', 'specialisation', 'mba_p', 'gender', 'degree_p', 'workex']

# %%
# selecting the common cols and will do training on these cols!
# these cols were selected as a nlargest result of 2 feature selection techniques!

train = df[commoncols]
train.head()
# Out:
#    ssc_p  hsc_p  degree_t  ssc_b  specialisation  mba_p  gender  degree_p  \
# 0  67.00  91.00         2      1               1  58.80       1     58.00
# 1  79.33  78.33         2      0               0  66.28       1     77.48
# 2  65.00  68.00         0      0               0  57.80       1     64.00
# 3  56.00  52.00         2      0               1  59.43       1     52.00
# 4  85.80  73.60         0      0               0  55.50       1     73.30
#
#    workex
# 0       0
# 1       1
# 2       0
# 3       0
# 4       0

# %%
'''
From the above DF we notice that gender,specialisation,degree_t,workex are the 
categorical columns and they make sense isn't it?,for any placement drive
students are first filtered on basis of their boards,sem scores which in this case are {mba_p,ssc_p,degree_p,hsc_p}
and then workexperience also matters a lot!,then specialisation as well,gender is also important
because now-a-days few companies focus on women empowerment,so yes,all the features make perfect sense!

'''
getmappings
# Out:
# {'gender': {'F': 0, 'M': 1},
#  'ssc_b': {'Central': 0, 'Others': 1},
#  'hsc_b': {'Central': 0, 'Others': 1},
#  'hsc_s': {'Arts': 0, 'Commerce': 1, 'Science': 2},
#  'degree_t': {'Comm&Mgmt': 0, 'Others': 1, 'Sci&Tech': 2},
#  'workex': {'No': 0, 'Yes': 1},
#  'specialisation': {'Mkt&Fin': 0, 'Mkt&HR': 1},
#  'status': {'Not Placed': 0, 'Placed': 1}}

# %%
train = train[['gender','specialisation','degree_t','workex','ssc_p','hsc_p','degree_p','mba_p']]
train.columns = ['Gender','Specialisation','Techinal Degree','Work Experience','SSC_p','High School_p','Degree_p','MBA_p']
train.head()
# Out:
#    Gender  Specialisation  Techinal Degree  Work Experience  SSC_p  \
# 0       1               1                2                0  67.00
# 1       1               0                2                1  79.33
# 2       1               0                0                0  65.00
# 3       1               1                2                0  56.00
# 4       1               0                0                0  85.80
#
#    High School_p  Degree_p  MBA_p
# 0          91.00     58.00  58.80
# 1          78.33     77.48  66.28
# 2          68.00     64.00  57.80
# 3          52.00     52.00  59.43
# 4          73.60     73.30  55.50

# %%
train['Techinal Degree'].value_counts()
# Out:
# 0    145
# 2     59
# 1     11
# Name: Techinal Degree, dtype: int64

# %% [markdown]
# ## Model Building

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split,RandomizedSearchCV,cross_val_score
from sklearn import metrics

# %%
X_train, X_test, y_train, y_test = train_test_split(train,test,test_size=0.2, random_state=12)
X_train.shape,X_test.shape
# Out:
# ((172, 8), (43, 8))

# %%
dc = DecisionTreeClassifier()
dc.fit(X_train,y_train)
plt.figure(figsize=(16,9))
tree.plot_tree(dc,filled=True,class_names=['Not_placed','Placed'],feature_names=train.columns.tolist())
# Out:
# [Text(0.34375, 0.9615384615384616, 'SSC_p <= 56.44\ngini = 0.435\nsamples = 172\nvalue = [55, 117]\nclass = Placed'),
#  Text(0.10714285714285714, 0.8846153846153846, 'Degree_p <= 70.655\ngini = 0.202\nsamples = 35\nvalue = [31, 4]\nclass = Not_placed'),
#  Text(0.07142857142857142, 0.8076923076923077, 'High School_p <= 58.5\ngini = 0.161\nsamples = 34\nvalue = [31, 3]\nclass = Not_placed'),
#  Text(0.03571428571428571, 0.7307692307692307, 'gini = 0.0\nsamples = 20\nvalue = [20, 0]\nclass = Not_placed'),
#  Text(0.10714285714285714, 0.7307692307692307, 'MBA_p <= 54.305\ngini = 0.337\nsamples = 14\nvalue = [11, 3]\nclass = Not_placed'),
#  Text(0.07142857142857142, 0.6538461538461539, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Placed'),
#  Text(0.14285714285714285, 0.6538461538461539, 'High School_p <= 61.665\ngini = 0.26\nsamples = 13\nvalue = [11, 2]\nclass = Not_placed'),
#  Text(0.10714285714285714, 0.5769230769230769, 'SSC_p <= 48.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Not_placed'),
#  Text(0.07142857142857142, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not_placed'),
#  Text(0.14285714285714285, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Placed'),
#  Text(0.17857142857142858, 0.5769230769230769, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = Not_placed'),
#  Text(0.14285714285714285, 0.8076923076923077, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Placed'),
#  Text(0.5803571428571429, 0.8846153846153846, 'High School_p <= 53.5\ngini = 0.289\nsamples = 137\nvalue = [24, 113]\nclass = Placed'),
#  Text(0.5446428571428571, 0.8076923076923077, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Not_placed'),
#  Text(0.6160714285714286, 0.8076923076923077, 'MBA_p <= 52.295\ngini = 0.256\nsamples = 133\nvalue = [20, 113]\nclass = Placed'),
#  Text(0.5803571428571429, 0.7307692307692307, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not_placed'),
#  Text(0.6517857142857143, 0.7307692307692307, 'MBA_p <= 68.92\ngini = 0.237\nsamples = 131\nvalue = [18, 113]\nclass = Placed'),
#  Text(0.48214285714285715, 0.6538461538461539, 'SSC_p <= 69.25\ngini = 0.165\nsamples = 110\nvalue = [10, 100]\nclass = Placed'),
#  Text(0.35714285714285715, 0.5769230769230769, 'MBA_p <= 60.425\ngini = 0.278\nsamples = 54\nvalue = [9, 45]\nclass = Placed'),
#  Text(0.21428571428571427, 0.5, 'Techinal Degree <= 1.5\ngini = 0.064\nsamples = 30\nvalue = [1, 29]\nclass = Placed'),
#  Text(0.17857142857142858, 0.4230769230769231, 'gini = 0.0\nsamples = 26\nvalue = [0, 26]\nclass = Placed'),
#  Text(0.25, 0.4230769230769231, 'Specialisation <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Placed'),
#  Text(0.21428571428571427, 0.34615384615384615, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Placed'),
#  Text(0.2857142857142857, 0.34615384615384615, 'SSC_p <= 63.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not_placed'),
#  Text(0.25, 0.2692307692307692, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not_placed'),
#  Text(0.32142857142857145, 0.2692307692307692, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Placed'),
#  Text(0.5, 0.5, 'High School_p <= 70.3\ngini = 0.444\nsamples = 24\nvalue = [8, 16]\nclass = Placed'),
#  Text(0.4642857142857143, 0.4230769230769231, 'Work Experience <= 0.5\ngini = 0.5\nsamples = 16\nvalue = [8, 8]\nclass = Not_placed'),
#  Text(0.42857142857142855, 0.34615384615384615, 'High School_p <= 61.5\ngini = 0.473\nsamples = 13\nvalue = [8, 5]\nclass = Not_placed'),
#  Text(0.39285714285714285, 0.2692307692307692, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Placed'),
#  Text(0.4642857142857143, 0.2692307692307692, 'MBA_p <= 64.255\ngini = 0.397\nsamples = 11\nvalue = [8, 3]\nclass = Not_placed'),
#  Text(0.42857142857142855, 0.19230769230769232, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = Not_placed'),
#  Text(0.5, 0.19230769230769232, 'High School_p <= 63.4\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = Placed'),
#  Text(0.4642857142857143, 0.11538461538461539, 'MBA_p <= 65.68\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Not_placed'),
#  Text(0.42857142857142855, 0.038461538461538464, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Placed'),
#  Text(0.5, 0.038461538461538464, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not_placed'),
#  Text(0.5357142857142857, 0.11538461538461539, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Placed'),
#  Text(0.5, 0.34615384615384615, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Placed'),
#  Text(0.5357142857142857, 0.4230769230769231, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = Placed'),
#  Text(0.6071428571428571, 0.5769230769230769, 'MBA_p <= 66.405\ngini = 0.035\nsamples = 56\nvalue = [1, 55]\nclass = Placed'),
#  Text(0.5714285714285714, 0.5, 'gini = 0.0\nsamples = 44\nvalue = [0, 44]\nclass = Placed'),
#  Text(0.6428571428571429, 0.5, 'MBA_p <= 66.61\ngini = 0.153\nsamples = 12\nvalue = [1, 11]\nclass = Placed'),
#  Text(0.6071428571428571, 0.4230769230769231, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not_placed'),
#  Text(0.6785714285714286, 0.4230769230769231, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]\nclass = Placed'),
#  Text(0.8214285714285714, 0.6538461538461539, 'Degree_p <= 66.1\ngini = 0.472\nsamples = 21\nvalue = [8, 13]\nclass = Placed'),
#  Text(0.75, 0.5769230769230769, 'MBA_p <= 72.215\ngini = 0.245\nsamples = 7\nvalue = [6, 1]\nclass = Not_placed'),
#  Text(0.7142857142857143, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = Not_placed'),
#  Text(0.7857142857142857, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Placed'),
#  Text(0.8928571428571429, 0.5769230769230769, 'High School_p <= 62.5\ngini = 0.245\nsamples = 14\nvalue = [2, 12]\nclass = Placed'),
#  Text(0.8571428571428571, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not_placed'),
#  Text(0.9285714285714286, 0.5, 'SSC_p <= 63.65\ngini = 0.142\nsamples = 13\nvalue = [1, 12]\nclass = Placed'),
#  Text(0.8928571428571429, 0.4230769230769231, 'Degree_p <= 72.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not_placed'),
#  Text(0.8571428571428571, 0.34615384615384615, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Placed'),
#  Text(0.9285714285714286, 0.34615384615384615, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not_placed'),
#  Text(0.9642857142857143, 0.4230769230769231, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]\nclass = Placed')]

# %%
costpath = dc.cost_complexity_pruning_path(train,test)
ccp_alpha,impurities = costpath.ccp_alphas,costpath.impurities

# %%
modellist = []
for alpha in ccp_alpha:
    dc = DecisionTreeClassifier(ccp_alpha=alpha)
    dc.fit(X_train,y_train)
    modellist.append(dc)

# %%
train_score = [clf.score(X_train,y_train) for clf in modellist]
test_score = [clf.score(X_test,y_test) for clf in modellist]

plt.xlabel('alpha_value')
plt.ylabel('accuracy')
plt.plot(ccp_alpha,train_score,label = 'train_score',marker = '+',color = 'magenta')
plt.plot(ccp_alpha,test_score,label = 'test_score',marker = '*',color = 'red')
plt.legend()
plt.show()

# %%
dc = DecisionTreeClassifier(ccp_alpha=0.0195)
dc.fit(X_train,y_train)
plt.figure(figsize=(15,7))
tree.plot_tree(dc,filled=True,class_names=['Not_placed','Placed'],feature_names=train.columns.tolist())
# Out:
# [Text(0.25, 0.9166666666666666, 'SSC_p <= 56.44\ngini = 0.435\nsamples = 172\nvalue = [55, 117]\nclass = Placed'),
#  Text(0.125, 0.75, 'gini = 0.202\nsamples = 35\nvalue = [31, 4]\nclass = Not_placed'),
#  Text(0.375, 0.75, 'High School_p <= 53.5\ngini = 0.289\nsamples = 137\nvalue = [24, 113]\nclass = Placed'),
#  Text(0.25, 0.5833333333333334, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Not_placed'),
#  Text(0.5, 0.5833333333333334, 'MBA_p <= 52.295\ngini = 0.256\nsamples = 133\nvalue = [20, 113]\nclass = Placed'),
#  Text(0.375, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not_placed'),
#  Text(0.625, 0.4166666666666667, 'MBA_p <= 68.92\ngini = 0.237\nsamples = 131\nvalue = [18, 113]\nclass = Placed'),
#  Text(0.5, 0.25, 'gini = 0.165\nsamples = 110\nvalue = [10, 100]\nclass = Placed'),
#  Text(0.75, 0.25, 'Degree_p <= 66.1\ngini = 0.472\nsamples = 21\nvalue = [8, 13]\nclass = Placed'),
#  Text(0.625, 0.08333333333333333, 'gini = 0.245\nsamples = 7\nvalue = [6, 1]\nclass = Not_placed'),
#  Text(0.875, 0.08333333333333333, 'gini = 0.245\nsamples = 14\nvalue = [2, 12]\nclass = Placed')]

# %% [markdown]
# # Hyperparameter Tuning

# %%
params = {
    'RandomForest':{
        'model': RandomForestClassifier(),
        'params':{
            'n_estimators': [int(x) for x in np.linspace(start=1,stop=1200,num=10)],
            'max_depth':[int(x) for x in np.linspace(start=1,stop=30,num=5)],
            'min_samples_split':[2,5,10,12],
            'min_samples_leaf':[2,5,10,12],
            'max_features':['auto','sqrt'],
            'ccp_alpha':[0.0185,0.0190,0.0195,0.0200],
        }
    },
    
    'logistic':{
        'model':LogisticRegression(),
        'params':{
            'penalty':['l1', 'l2', 'elasticnet'],
            'C':[0.25,0.50,0.75,1.0],
            'tol':[1e-10,1e-5,1e-4,1e-3,0.025,0.25,0.50],
            'solver':['lbfgs','liblinear','saga','newton-cg'],
            'multi_class':['auto', 'ovr', 'multinomial'],
            'max_iter':[int(x) for x in np.linspace(start=1,stop=250,num=10)],
        }
    },
    'D-tree':{
        'model':DecisionTreeClassifier(),
        'params':{
            'criterion':['gini','entropy'],
            'splitter':['best','random'],
            'min_samples_split':[1,2,5,10,12],
            'min_samples_leaf':[1,2,5,10,12],
            'max_features':['auto','sqrt'],
            'ccp_alpha':[0.0185,0.0190,0.0195,0.0200],
        }
    },
    'SVM':{
        'model':SVC(),
        'params':{
            'C':[0.25,0.50,0.75,1.0],
            'tol':[1e-10,1e-5,1e-4,0.025,0.50,0.75],
            'kernel':['linear','poly','sigmoid','rbf'],
            'max_iter':[int(x) for x in np.linspace(start=1,stop=250,num=10)],
        }
    }
}

# %%
scores = []
for model_name,mp in params.items():
    
    clf = RandomizedSearchCV(mp['model'],param_distributions=mp['params'],cv=5,n_iter=10,n_jobs=-1,scoring='accuracy')
    clf.fit(X_train,y_train)
    scores.append({
        'model_name':model_name,
        'best_score':clf.best_score_,
        'best_estimator':clf.best_estimator_
    })
# Out:
# C:\Users\anups\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 20 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 11 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\anups\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\anups\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\anups\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\anups\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 9 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\anups\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\anups\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\anups\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\anups\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\anups\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [       nan 0.70941176 0.7907563         nan        nan 0.84252101
#  0.84252101 0.84235294 0.84252101        nan]
#   warnings.warn(
# C:\Users\anups\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 35 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\anups\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\anups\anaconda3\Lib\site-packages\sklearn\base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\anups\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1168, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\anups\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 56, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\anups\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\anups\anaconda3\Lib\site-packages\sklearn\base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\anups\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1178, in fit
#     raise ValueError("l1_ratio must be specified when penalty is elasticnet.")
# ValueError: l1_ratio must be specified when penalty is elasticnet.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\anups\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\anups\anaconda3\Lib\site-packages\sklearn\base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\anups\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1168, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\anups\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 56, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\anups\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\anups\anaconda3\Lib\site-packages\sklearn\base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\anups\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1168, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\anups\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 56, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\anups\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [0.83647059        nan        nan        nan 0.81344538        nan
#         nan        nan 0.84823529        nan]
#   warnings.warn(
# C:\Users\anups\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\anups\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 30 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 14 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\anups\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\anups\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\anups\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\anups\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 11 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\anups\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\anups\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\anups\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\anups\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\anups\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\anups\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\anups\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\anups\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_samples_split' parameter of DecisionTreeClassifier must be an int in the range [2, inf) or a float in the range (0.0, 1.0]. Got 1 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\anups\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [0.72672269        nan 0.8307563         nan        nan 0.81361345
#         nan        nan        nan 0.7605042 ]
#   warnings.warn(

# %%
scores_df = pd.DataFrame(data = scores,columns = ['model_name','best_score','best_estimator'])
scores_df.head()
# Out:
#      model_name  best_score                                     best_estimator
# 0  RandomForest    0.842521  (DecisionTreeClassifier(ccp_alpha=0.0185, max_...
# 1      logistic    0.848235  LogisticRegression(C=0.5, max_iter=56, penalty...
# 2        D-tree    0.830756  DecisionTreeClassifier(ccp_alpha=0.0195, crite...
# 3           SVM    0.836807          SVC(kernel='poly', max_iter=167, tol=0.5)

# %%
scores
# Out:
# [{'model_name': 'RandomForest',
#   'best_score': 0.8425210084033612,
#   'best_estimator': RandomForestClassifier(ccp_alpha=0.0185, max_depth=8, min_samples_leaf=12,
#                          min_samples_split=10, n_estimators=933)},
#  {'model_name': 'logistic',
#   'best_score': 0.8482352941176469,
#   'best_estimator': LogisticRegression(C=0.5, max_iter=56, penalty='l1', solver='liblinear',
#                      tol=1e-05)},
#  {'model_name': 'D-tree',
#   'best_score': 0.8307563025210083,
#   'best_estimator': DecisionTreeClassifier(ccp_alpha=0.0195, criterion='entropy',
#                          max_features='sqrt', min_samples_leaf=2,
#                          min_samples_split=12)},
#  {'model_name': 'SVM',
#   'best_score': 0.8368067226890756,
#   'best_estimator': SVC(kernel='poly', max_iter=167, tol=0.5)}]

# %%
# random forest model


rf = RandomForestClassifier(ccp_alpha=0.02, max_depth=30, max_features='sqrt',
                         min_samples_leaf=2, min_samples_split=12,
                         n_estimators=100,random_state=46)
rf.fit(X_train.values,y_train)
y_pred = rf.predict(X_test.values)
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# 0.8604651162790697

# %%
# logistic regression

lr = LogisticRegression(C=0.25, max_iter=111, multi_class='ovr', solver='newton-cg',
                     tol=1e-05)

lr.fit(X_train.values,y_train)
y_pred = lr.predict(X_test.values)
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# 0.9534883720930233

# %%
# decision tree

dc = DecisionTreeClassifier(ccp_alpha=0.019, criterion='entropy',
                          min_samples_leaf=5,
                         min_samples_split=5, splitter='random')
dc.fit(X_train,y_train)
y_pred = dc.predict(X_test)
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# 0.8604651162790697

# %%
print(metrics.classification_report(y_test,rf.predict(X_test.values)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.88      0.94      0.91        31
#
#     accuracy                           0.86        43
#    macro avg       0.84      0.80      0.82        43
# weighted avg       0.86      0.86      0.86        43

# %%
cn = metrics.confusion_matrix(y_test,rf.predict(X_test.values))
sn.heatmap(cn,annot=True,cmap='plasma')
# Out:
# <Axes: >

# %% [markdown]
# # Model Testing

# %%
traindata = np.array(train)
predicted = []
for i in range(len(traindata)):
    predicted.append(rf.predict([traindata[i]]))
    
predicted
# Out:
# [array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1])]

# %%
resultdf = train.copy()
resultdf['Actual'] = np.array(test)
resultdf['Predicted'] = np.array(predicted)
resultdf.head()
# Out:
#    Gender  Specialisation  Techinal Degree  Work Experience  SSC_p  \
# 0       1               1                2                0  67.00
# 1       1               0                2                1  79.33
# 2       1               0                0                0  65.00
# 3       1               1                2                0  56.00
# 4       1               0                0                0  85.80
#
#    High School_p  Degree_p  MBA_p  Actual  Predicted
# 0          91.00     58.00  58.80       1          1
# 1          78.33     77.48  66.28       1          1
# 2          68.00     64.00  57.80       1          1
# 3          52.00     52.00  59.43       0          0
# 4          73.60     73.30  55.50       1          1

# %%
resultdf['Actual'].value_counts()
# Out:
# 1    148
# 0     67
# Name: Actual, dtype: int64

# %%
resultdf['Predicted'].value_counts()
# Out:
# 1    166
# 0     49
# Name: Predicted, dtype: int64

# %%
getmappings
# Out:
# {'gender': {'F': 0, 'M': 1},
#  'ssc_b': {'Central': 0, 'Others': 1},
#  'hsc_b': {'Central': 0, 'Others': 1},
#  'hsc_s': {'Arts': 0, 'Commerce': 1, 'Science': 2},
#  'degree_t': {'Comm&Mgmt': 0, 'Others': 1, 'Sci&Tech': 2},
#  'workex': {'No': 0, 'Yes': 1},
#  'specialisation': {'Mkt&Fin': 0, 'Mkt&HR': 1},
#  'status': {'Not Placed': 0, 'Placed': 1}}

# %% [markdown]
# ### Predicted Probability

# %%
traindata = np.array(train)
predicted = []
for i in range(len(traindata)):
    predicted.append(rf.predict_proba([traindata[i]]))
    
predicted
# Out:
# [array([[0.26516754, 0.73483246]]),
#  array([[0.09156159, 0.90843841]]),
#  array([[0.16944829, 0.83055171]]),
#  array([[0.85609822, 0.14390178]]),
#  array([[0.09381536, 0.90618464]]),
#  array([[0.76314963, 0.23685037]]),
#  array([[0.76633249, 0.23366751]]),
#  array([[0.10257903, 0.89742097]]),
#  array([[0.09380454, 0.90619546]]),
#  array([[0.48249149, 0.51750851]]),
#  array([[0.32650905, 0.67349095]]),
#  array([[0.09308286, 0.90691714]]),
#  array([[0.8857402, 0.1142598]]),
#  array([[0.27664585, 0.72335415]]),
#  array([[0.77386444, 0.22613556]]),
#  array([[0.10998562, 0.89001438]]),
#  array([[0.16498457, 0.83501543]]),
#  array([[0.68693291, 0.31306709]]),
#  array([[0.43423599, 0.56576401]]),
#  array([[0.20760915, 0.79239085]]),
#  array([[0.15218428, 0.84781572]]),
#  array([[0.12622064, 0.87377936]]),
#  array([[0.20730926, 0.79269074]]),
#  array([[0.1492675, 0.8507325]]),
#  array([[0.14824883, 0.85175117]]),
#  array([[0.8530756, 0.1469244]]),
#  array([[0.08609576, 0.91390424]]),
#  array([[0.14568954, 0.85431046]]),
#  array([[0.08750644, 0.91249356]]),
#  array([[0.47357786, 0.52642214]]),
#  array([[0.15506455, 0.84493545]]),
#  array([[0.54784412, 0.45215588]]),
#  array([[0.21069624, 0.78930376]]),
#  array([[0.1716402, 0.8283598]]),
#  array([[0.78818212, 0.21181788]]),
#  array([[0.13415677, 0.86584323]]),
#  array([[0.90679017, 0.09320983]]),
#  array([[0.18334916, 0.81665084]]),
#  array([[0.16796007, 0.83203993]]),
#  array([[0.19726961, 0.80273039]]),
#  array([[0.10096759, 0.89903241]]),
#  array([[0.32505749, 0.67494251]]),
#  array([[0.8576678, 0.1423322]]),
#  array([[0.11044099, 0.88955901]]),
#  array([[0.10858349, 0.89141651]]),
#  array([[0.18326656, 0.81673344]]),
#  array([[0.37413612, 0.62586388]]),
#  array([[0.24436668, 0.75563332]]),
#  array([[0.15865006, 0.84134994]]),
#  array([[0.90311552, 0.09688448]]),
#  array([[0.1246206, 0.8753794]]),
#  array([[0.7413927, 0.2586073]]),
#  array([[0.92243738, 0.07756262]]),
#  array([[0.15002747, 0.84997253]]),
#  array([[0.16296307, 0.83703693]]),
#  array([[0.22219168, 0.77780832]]),
#  array([[0.28503736, 0.71496264]]),
#  array([[0.09760854, 0.90239146]]),
#  array([[0.10289619, 0.89710381]]),
#  array([[0.48271211, 0.51728789]]),
#  array([[0.08994328, 0.91005672]]),
#  array([[0.09521523, 0.90478477]]),
#  array([[0.11734893, 0.88265107]]),
#  array([[0.29098189, 0.70901811]]),
#  array([[0.09270425, 0.90729575]]),
#  array([[0.88639938, 0.11360062]]),
#  array([[0.10858866, 0.89141134]]),
#  array([[0.09446896, 0.90553104]]),
#  array([[0.52808976, 0.47191024]]),
#  array([[0.09101257, 0.90898743]]),
#  array([[0.18983844, 0.81016156]]),
#  array([[0.09556268, 0.90443732]]),
#  array([[0.10889033, 0.89110967]]),
#  array([[0.0924887, 0.9075113]]),
#  array([[0.2662528, 0.7337472]]),
#  array([[0.31610566, 0.68389434]]),
#  array([[0.11003207, 0.88996793]]),
#  array([[0.1378355, 0.8621645]]),
#  array([[0.12050233, 0.87949767]]),
#  array([[0.23778835, 0.76221165]]),
#  array([[0.13460947, 0.86539053]]),
#  array([[0.1236328, 0.8763672]]),
#  array([[0.16236881, 0.83763119]]),
#  array([[0.09123051, 0.90876949]]),
#  array([[0.10556397, 0.89443603]]),
#  array([[0.16103508, 0.83896492]]),
#  array([[0.21865488, 0.78134512]]),
#  array([[0.70899288, 0.29100712]]),
#  array([[0.17683467, 0.82316533]]),
#  array([[0.11316226, 0.88683774]]),
#  array([[0.09451688, 0.90548312]]),
#  array([[0.87305109, 0.12694891]]),
#  array([[0.19325921, 0.80674079]]),
#  array([[0.73424971, 0.26575029]]),
#  array([[0.23430576, 0.76569424]]),
#  array([[0.10934162, 0.89065838]]),
#  array([[0.09415204, 0.90584796]]),
#  array([[0.41913565, 0.58086435]]),
#  array([[0.15608642, 0.84391358]]),
#  array([[0.55797274, 0.44202726]]),
#  array([[0.86585852, 0.13414148]]),
#  array([[0.14345659, 0.85654341]]),
#  array([[0.09239762, 0.90760238]]),
#  array([[0.11503118, 0.88496882]]),
#  array([[0.16233338, 0.83766662]]),
#  array([[0.38430506, 0.61569494]]),
#  array([[0.7639369, 0.2360631]]),
#  array([[0.19107045, 0.80892955]]),
#  array([[0.13414071, 0.86585929]]),
#  array([[0.6164853, 0.3835147]]),
#  array([[0.13745204, 0.86254796]]),
#  array([[0.88975873, 0.11024127]]),
#  array([[0.31569774, 0.68430226]]),
#  array([[0.09782956, 0.90217044]]),
#  array([[0.11065497, 0.88934503]]),
#  array([[0.11997164, 0.88002836]]),
#  array([[0.10807005, 0.89192995]]),
#  array([[0.10163931, 0.89836069]]),
#  array([[0.12010389, 0.87989611]]),
#  array([[0.19595437, 0.80404563]]),
#  array([[0.70882907, 0.29117093]]),
#  array([[0.20160175, 0.79839825]]),
#  array([[0.15537749, 0.84462251]]),
#  array([[0.12156231, 0.87843769]]),
#  array([[0.19767689, 0.80232311]]),
#  array([[0.16726096, 0.83273904]]),
#  array([[0.11507076, 0.88492924]]),
#  array([[0.12610387, 0.87389613]]),
#  array([[0.16712304, 0.83287696]]),
#  array([[0.0881738, 0.9118262]]),
#  array([[0.42153477, 0.57846523]]),
#  array([[0.3259755, 0.6740245]]),
#  array([[0.18898819, 0.81101181]]),
#  array([[0.11307374, 0.88692626]]),
#  array([[0.09150157, 0.90849843]]),
#  array([[0.26241677, 0.73758323]]),
#  array([[0.69563051, 0.30436949]]),
#  array([[0.12445299, 0.87554701]]),
#  array([[0.16836074, 0.83163926]]),
#  array([[0.19002559, 0.80997441]]),
#  array([[0.09786212, 0.90213788]]),
#  array([[0.38013835, 0.61986165]]),
#  array([[0.09529909, 0.90470091]]),
#  array([[0.10250379, 0.89749621]]),
#  array([[0.8814873, 0.1185127]]),
#  array([[0.12854383, 0.87145617]]),
#  array([[0.16440415, 0.83559585]]),
#  array([[0.14489621, 0.85510379]]),
#  array([[0.28028308, 0.71971692]]),
#  array([[0.80734653, 0.19265347]]),
#  array([[0.21343174, 0.78656826]]),
#  array([[0.1058062, 0.8941938]]),
#  array([[0.13082707, 0.86917293]]),
#  array([[0.57407007, 0.42592993]]),
#  array([[0.61249561, 0.38750439]]),
#  array([[0.73076657, 0.26923343]]),
#  array([[0.14848708, 0.85151292]]),
#  array([[0.25437816, 0.74562184]]),
#  array([[0.21976302, 0.78023698]]),
#  array([[0.91796783, 0.08203217]]),
#  array([[0.24010124, 0.75989876]]),
#  array([[0.86837181, 0.13162819]]),
#  array([[0.08872281, 0.91127719]]),
#  array([[0.28196085, 0.71803915]]),
#  array([[0.23323093, 0.76676907]]),
#  array([[0.25942217, 0.74057783]]),
#  array([[0.31923271, 0.68076729]]),
#  array([[0.19496222, 0.80503778]]),
#  array([[0.88787648, 0.11212352]]),
#  array([[0.69846023, 0.30153977]]),
#  array([[0.55184874, 0.44815126]]),
#  array([[0.08872281, 0.91127719]]),
#  array([[0.3102324, 0.6897676]]),
#  array([[0.89863828, 0.10136172]]),
#  array([[0.5252487, 0.4747513]]),
#  array([[0.23901022, 0.76098978]]),
#  array([[0.36485462, 0.63514538]]),
#  array([[0.1145677, 0.8854323]]),
#  array([[0.25764054, 0.74235946]]),
#  array([[0.4107069, 0.5892931]]),
#  array([[0.14554815, 0.85445185]]),
#  array([[0.27487698, 0.72512302]]),
#  array([[0.67492787, 0.32507213]]),
#  array([[0.10687173, 0.89312827]]),
#  array([[0.62775266, 0.37224734]]),
#  array([[0.18399524, 0.81600476]]),
#  array([[0.73307739, 0.26692261]]),
#  array([[0.09748035, 0.90251965]]),
#  array([[0.7584989, 0.2415011]]),
#  array([[0.52190002, 0.47809998]]),
#  array([[0.4106159, 0.5893841]]),
#  array([[0.1104668, 0.8895332]]),
#  array([[0.10014624, 0.89985376]]),
#  array([[0.34729204, 0.65270796]]),
#  array([[0.89871458, 0.10128542]]),
#  array([[0.10268699, 0.89731301]]),
#  array([[0.10242439, 0.89757561]]),
#  array([[0.50106721, 0.49893279]]),
#  array([[0.42678464, 0.57321536]]),
#  array([[0.28896465, 0.71103535]]),
#  array([[0.12195119, 0.87804881]]),
#  array([[0.72641898, 0.27358102]]),
#  array([[0.14674664, 0.85325336]]),
#  array([[0.55429226, 0.44570774]]),
#  array([[0.10094789, 0.89905211]]),
#  array([[0.16095374, 0.83904626]]),
#  array([[0.89678223, 0.10321777]]),
#  array([[0.25549544, 0.74450456]]),
#  array([[0.70646076, 0.29353924]]),
#  array([[0.16585554, 0.83414446]]),
#  array([[0.15933448, 0.84066552]]),
#  array([[0.19457232, 0.80542768]]),
#  array([[0.11260645, 0.88739355]]),
#  array([[0.35096943, 0.64903057]]),
#  array([[0.48724611, 0.51275389]])]

# %%
predicted[0][0],predicted[0][0][0],predicted[0][0][1]
# Out:
# (array([0.26516754, 0.73483246]), 0.2651675438096203, 0.7348324561903798)

# %%
resultdf['Prob_not_getting_placed'] = np.array([predicted[i][0][0] for i in range(len(predicted))])
resultdf['Prob_getting_placed'] = np.array([predicted[i][0][1] for i in range(len(predicted))])
resultdf.head(30)
# Out:
#     Gender  Specialisation  Techinal Degree  Work Experience  SSC_p  \
# 0        1               1                2                0  67.00
# 1        1               0                2                1  79.33
# 2        1               0                0                0  65.00
# 3        1               1                2                0  56.00
# 4        1               0                0                0  85.80
# 5        1               0                2                1  55.00
# 6        0               0                0                0  46.00
# 7        1               0                2                1  82.00
# 8        1               0                0                0  73.00
# 9        1               0                0                0  58.00
# 10       1               1                0                1  58.00
# 11       1               0                0                1  69.60
# 12       0               1                0                0  47.00
# 13       0               0                0                0  77.00
# 14       1               1                0                0  62.00
# 15       0               0                0                1  65.00
# 16       1               0                0                1  63.00
# 17       0               0                0                0  55.00
# 18       0               1                0                0  63.00
# 19       1               0                0                1  60.00
# 20       1               1                0                0  62.00
# 21       0               0                0                0  79.00
# 22       0               1                2                0  69.80
# 23       0               0                2                1  77.40
# 24       1               0                2                0  76.50
# 25       0               0                0                1  52.58
# 26       1               0                0                1  71.00
# 27       1               1                0                0  63.00
# 28       1               0                0                1  76.76
# 29       1               0                0                0  62.00
#
#     High School_p  Degree_p  MBA_p  Actual  Predicted  \
# 0           91.00     58.00  58.80       1          1
# 1           78.33     77.48  66.28       1          1
# 2           68.00     64.00  57.80       1          1
# 3           52.00     52.00  59.43       0          0
# 4           73.60     73.30  55.50       1          1
# 5           49.80     67.25  51.58       0          0
# 6           49.20     79.00  53.29       0          0
# 7           64.00     66.00  62.14       1          1
# 8           79.00     72.00  61.29       1          1
# 9           70.00     61.00  52.21       0          1
# 10          61.00     60.00  60.85       1          1
# 11          68.40     78.30  63.70       1          1
# 12          55.00     65.00  65.04       0          0
# 13          87.00     59.00  68.63       1          1
# 14          47.00     50.00  54.96       0          0
# 15          75.00     69.00  64.66       1          1
# 16          66.20     65.60  62.54       1          1
# 17          67.00     64.00  67.28       0          0
# 18          66.00     64.00  64.08       0          1
# 19          67.00     70.00  77.89       1          1
# 20          65.00     66.00  56.70       1          1
# 21          76.00     85.00  69.06       1          1
# 22          60.80     72.23  68.81       1          1
# 23          60.00     64.74  63.62       1          1
# 24          97.70     78.86  74.01       1          1
# 25          54.60     50.20  65.33       0          0
# 26          79.00     66.00  57.55       1          1
# 27          67.00     66.00  57.69       1          1
# 28          76.50     67.50  64.15       1          1
# 29          67.00     58.00  51.29       0          1
#
#     Prob_not_getting_placed  Prob_getting_placed
# 0                  0.265168             0.734832
# 1                  0.091562             0.908438
# 2                  0.169448             0.830552
# 3                  0.856098             0.143902
# 4                  0.093815             0.906185
# 5                  0.763150             0.236850
# 6                  0.766332             0.233668
# 7                  0.102579             0.897421
# 8                  0.093805             0.906195
# 9                  0.482491             0.517509
# 10                 0.326509             0.673491
# 11                 0.093083             0.906917
# 12                 0.885740             0.114260
# 13                 0.276646             0.723354
# 14                 0.773864             0.226136
# 15                 0.109986             0.890014
# 16                 0.164985             0.835015
# 17                 0.686933             0.313067
# 18                 0.434236             0.565764
# 19                 0.207609             0.792391
# 20                 0.152184             0.847816
# 21                 0.126221             0.873779
# 22                 0.207309             0.792691
# 23                 0.149267             0.850733
# 24                 0.148249             0.851751
# 25                 0.853076             0.146924
# 26                 0.086096             0.913904
# 27                 0.145690             0.854310
# 28                 0.087506             0.912494
# 29                 0.473578             0.526422

# %%
# saving the model

import pickle
file = open('campusplacementpredictor.pkl','wb')
pickle.dump(rf,file)
file.close()
